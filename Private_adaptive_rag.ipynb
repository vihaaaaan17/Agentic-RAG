# %%
# %%capture --no-display
# !pip install --prefer-binary pathway

# %%
import logging
logging.basicConfig(level=logging.CRITICAL)

# %%
# !pip install "litellm>=1.35"
# Out:
# Requirement already satisfied: litellm>=1.35 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (1.50.1)
# Requirement already satisfied: aiohttp in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (3.9.3)
# Requirement already satisfied: click in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (8.1.7)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (8.4.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (3.1.4)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (4.23.0)
# Requirement already satisfied: openai>=1.52.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (1.52.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (2.9.2)
# Requirement already satisfied: python-dotenv>=0.2.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (2.32.3)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (0.7.0)
# Requirement already satisfied: tokenizers in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from litellm>=1.35) (0.20.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.35) (3.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.35) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.35) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.35) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.35) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.35) (0.9.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (0.25.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (0.5.0)
# Requirement already satisfied: sniffio in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.52.0->litellm>=1.35) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.0->litellm>=1.35) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.0.0->litellm>=1.35) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->litellm>=1.35) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->litellm>=1.35) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->litellm>=1.35) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.31.0->litellm>=1.35) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from tiktoken>=0.7.0->litellm>=1.35) (2024.9.11)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm>=1.35) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm>=1.35) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm>=1.35) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->litellm>=1.35) (1.9.4)
# Requirement already satisfied: colorama in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from click->litellm>=1.35) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from tokenizers->litellm>=1.35) (0.25.2)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.52.0->litellm>=1.35) (0.18.0)
# Requirement already satisfied: filelock in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.35) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.35) (2023.9.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.35) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.35) (6.0.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from httpcore<0.19.0,>=0.18.0->httpx<1,>=0.23.0->openai>=1.52.0->litellm>=1.35) (0.14.0)
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Lastly, we install [Sentence-Transformers](https://sbert.net/) for embedding the chunked texts.

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.45.2)
# Requirement already satisfied: tqdm in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: scikit-learn in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.25.2)
# Requirement already satisfied: Pillow in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (10.0.0)
# Requirement already satisfied: filelock in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.9.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.0)
# Requirement already satisfied: jinja2 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: colorama in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.25.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 2. Data Loading
# We will start by testing our solution with a static sample of knowledge data. We have prepared a sample for download for use in the  [adaptive-rag-contexts.jsonl](https://public-pathway-releases.s3.eu-central-1.amazonaws.com/data/adaptive-rag-contexts.jsonl) file, with ~1000 contexts from the SQUAD dataset, taken from Wikipedia texts.

# %%
# !wget -q -nc https://public-pathway-releases.s3.eu-central-1.amazonaws.com/data/adaptive-rag-contexts.jsonl
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Next, let’s do the necessary imports.

# %%
# !pip install pathway
# Out:
# Requirement already satisfied: pathway in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (0.post1)
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pathway as pw
# Out:
# This is not the real Pathway package.
# Visit https://pathway.com/developers/ to get Pathway.
# Already tried that? Visit https://pathway.com/troubleshooting/ to get help.
# Note: your platform is Windows-10-10.0.22631-SP0, your Python is CPython 3.11.4.

# %%
# To use advanced features with Pathway Scale, get your free license key from
# https://pathway.com/features and paste it below.
# To use Pathway Community, comment out the line below.
pw.set_license_key("03965F-C6A828-2ACAF1-90AA03-2FF25B-V3")
# Out:
# This is not the real Pathway package.
# Visit https://pathway.com/developers/ to get Pathway.
# Already tried that? Visit https://pathway.com/troubleshooting/ to get help.
# Note: your platform is Windows-10-10.0.22631-SP0, your Python is CPython 3.11.4.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 # To use advanced features with Pathway Scale, get your free license key from
#       2 # https://pathway.com/features and paste it below.
#       3 # To use Pathway Community, comment out the line below.
# ----> 4 pw.set_license_key("03965F-C6A828-2ACAF1-90AA03-2FF25B-V3")
#
# File c:\Users\agrvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pathway\__init__.py:61, in __getattr__(name)
#      59 _warn(warning)
#      60 error = error + "\n" + warning
# ---> 61 raise AttributeError(error)
#
# AttributeError: module 'pathway' has no attribute 'set_license_key'
# This is not the real Pathway package.
# Visit https://pathway.com/developers/ to get Pathway.
# Already tried that? Visit https://pathway.com/troubleshooting/ to get help.
# Note: your platform is Windows-10-10.0.22631-SP0, your Python is CPython 3.11.4.

# %%
from pathway.stdlib.indexing import default_vector_document_index
from pathway.xpacks.llm import embedders
from pathway.xpacks.llm.llms import LiteLLMChat
from pathway.xpacks.llm.question_answering import (
    answer_with_geometric_rag_strategy_from_index,
)

# %%
# Load documents in which answers will be searched
class InputSchema(pw.Schema):
    doc: str


documents = pw.io.fs.read(
    "adaptive-rag-contexts.jsonl",
    format="json",
    schema=InputSchema,
    json_field_paths={"doc": "/context"},
    mode="static",
)

# %% [markdown]
# When testing during development, we can run this code in a "static" way and check if all the sources are correctly loaded. Later, in production, the Pathway service running our code will know how to refresh the loaded documents when new data arrives.

# %%
# Create a table with example questions
df = pd.DataFrame(
    {
        "query": [
            "When it is burned what does hydrogen make?",
            "What was undertaken in 2010 to determine where dogs originated from?",
            # "What did Arnold's journey into politics look like?",
        ]
    }
)
query = pw.debug.table_from_pandas(df)

# %% [markdown]
# ### 3. Embedding Model Selection

# %% [markdown]
# We use `pathway.xpacks.llm.embedders` module to load open-source embedding models from the HuggingFace model library. For our showcase, we pick the `avsolatorio/GIST-small-Embedding-v0` model which has a dimension of 384.

# %%
embedding_model = "avsolatorio/GIST-small-Embedding-v0"

embedder = embedders.SentenceTransformerEmbedder(
    embedding_model, call_kwargs={"show_progress_bar": False}
)  # disable verbose logs
embedding_dimension: int = embedder.get_embedding_dimension()
print("Embedding dimension:", embedding_dimension)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/68.0k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/719 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding dimension: 384

# %%
# embedder = LiteLLMEmbedder(
#     capacity = 5,
#     retry_strategy = pw.udfs.ExponentialBackoffRetryStrategy(max_retries=4, initial_delay=1200),
#     model = "mistral/mistral-embed",
#     api_key=<mistral_api_key>,
# )
# Out:
#   File "<ipython-input-16-a1a94f63619b>", line 5
#     api_key=<mistral_api_key>,
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 5. LLM Initialization
#
# We now initialize the LLM instance that will call our local model.

# %%
model = LiteLLMChat(
    model="ollama/mistral",
    temperature=0,
    top_p=1,
    api_base="http://localhost:11434",  # local deployment
    format="json",  # only available in Ollama local deploy, do not use in Mistral API
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = LiteLLMChat(
#       2     model="ollama/mistral",
#       3     temperature=0,
#       4     top_p=1,
#       5     api_base="http://localhost:11434",  # local deployment
#       6     format="json",  # only available in Ollama local deploy, do not use in Mistral API
#       7 )
#
# NameError: name 'LiteLLMChat' is not defined

# %% [markdown]
# ### 6. Vector Document Index Creation
# We continue our pipeline code to specify the index with documents and embedding model to use when processing documents.

# %%
index = default_vector_document_index(
    documents.doc, documents, embedder=embedder, dimensions=embedding_dimension
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 index = default_vector_document_index(
#       2     documents.doc, documents, embedder=embedder, dimensions=embedding_dimension
#       3 )
#
# NameError: name 'default_vector_document_index' is not defined

# %% [markdown]
# **7.Retriver**

# %%
result = query.select(
    question=query.query,
    result=answer_with_geometric_rag_strategy_from_index(
        query.query,
        index,
        documents.doc,
        model,
        n_starting_documents=2,
        factor=2,
        max_iterations=4,
        strict_prompt=True,  # needed for open source models, instructs LLM to give JSON output strictly
    ),
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 result = query.select(
#       2     question=query.query,
#       3     result=answer_with_geometric_rag_strategy_from_index(
#       4         query.query,
#       5         index,
#       6         documents.doc,
#       7         model,
#       8         n_starting_documents=2,
#       9         factor=2,
#      10         max_iterations=4,
#      11         strict_prompt=True,  # needed for open source models, instructs LLM to give JSON output strictly
#      12     ),
#      13 )
#
# NameError: name 'query' is not defined

# %%
pw.debug.compute_and_print(result)
# Out:
# This is not the real Pathway package.
# Visit https://pathway.com/developers/ to get Pathway.
# Already tried that? Visit https://pathway.com/troubleshooting/ to get help.
# Note: your platform is Windows-10-10.0.22631-SP0, your Python is CPython 3.11.4.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pw.debug.compute_and_print(result)
#
# File c:\Users\agrvi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pathway\__init__.py:61, in __getattr__(name)
#      59 _warn(warning)
#      60 error = error + "\n" + warning
# ---> 61 raise AttributeError(error)
#
# AttributeError: module 'pathway' has no attribute 'debug'
# This is not the real Pathway package.
# Visit https://pathway.com/developers/ to get Pathway.
# Already tried that? Visit https://pathway.com/troubleshooting/ to get help.
# Note: your platform is Windows-10-10.0.22631-SP0, your Python is CPython 3.11.4.
